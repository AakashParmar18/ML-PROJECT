# %% [markdown]
# <a href="https://colab.research.google.com/github/AakashParmar18/ML-PROJECT/blob/main/Housing_Price_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
df=pd.read_excel("/content/HData.xlsx")
y=df.price
x=df.iloc[0:,1:13]
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=0)
model=LinearRegression()
model.fit(x_train,y_train)
c=model.intercept_
m=model.coef_
y_pred_train=model.predict(x_train)
plt.scatter(y_train,y_pred_train)
plt.show()
from sklearn.metrics import r2_score
r2_score(y_train,y_pred_train)
# Out:
# 0.6575703217254214
